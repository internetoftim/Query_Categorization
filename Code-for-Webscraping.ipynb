# %% [markdown]
# ## Extract Info from Youtube Videos

# %%
import bs4

# %% [markdown]
# Importing BeautifulSoup4 for parsing HTML page.

# %% [markdown]
# ## Using urllib
# this is for local testing

# %%
from urllib.request import urlopen as uReq
# from urllib2 import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
my_url = 'https://www.youtube.com/watch?v=xJbckXcpX1Q&list=PL4Yp_5ExVAU1n7rgLgGYFdy7WAppoQ870'

# %%
uClient = uReq(my_url)
page_html = uClient.read()	
soup_out= soup(page_html, "html.parser")

# %% [markdown]
# uReq(my_url) opens the URL that is stored in the variable my_url
# uClient.read() reads the html_page of Youtube
# soup(page_html, "html.parser") parsing HTML

# %%
for h4 in soup.findAll('h4'):
    print(h4.text)

# %%
my_url = 'https://www.youtube.com/watch?v=hUZS6yW0fQk'
my_url = 'https://www.youtube.com/watch?v=95zSs86SfmE'

# %%
def extract_meta(soup_base,prop_name,attribute_name):
    temp = soup_out.find_all('meta',{prop_name:attribute_name})
    for element in temp:
        out =(element.attrs["content"])    
    return out
        
def extract_video_info(my_url):
    uClient = uReq(my_url)
    page_html = uClient.read()	
    soup_out= soup(page_html, "html.parser")    
    out_title=extract_meta(soup_out,"name","title")
    out_keys=extract_meta(soup_out,"name","keywords")

    temp = soup_out.find_all('script',{'type':'application/ld+json'})[0]
    description=extract_meta(soup_out,"itemprop","description")
    category=extract_meta(soup_out,"itemprop","genre")
    viewcount=extract_meta(soup_out,"itemprop","interactionCount")
    twitter_description=extract_meta(soup_out,"name","twitter:description")
    channelID=extract_meta(soup_out,"itemprop","channelId")

    for string in temp.strings:
        a=json.loads(string)
        author = a['itemListElement'][0]['item']['name']    
        
    return out_title, out_keys,author, \
        category,viewcount,description, \
        twitter_description,channelID    \

# %%
t,k,a,c,v,d,td,chid = extract_video_info(my_url)

# %%
print(t,k,a,c,v,d,td,chid)

# %% [markdown]
# ## Using urllib2
# use this for westeros

# %%
import urllib2
import json
from bs4 import BeautifulSoup as soup
import bs4
from time import sleep

# %%
my_url = 'https://www.youtube.com/watch?v=e7t4pTNZshA'
page_html= urllib2.urlopen(my_url).read()
soup_out = bs4.BeautifulSoup(page_html)

# %%
# soup_out

# %%
# page_html

# %%
# page= "".join(page_html.split())
# page

# %%
def extract_meta(soup_base,prop_name,attribute_name):
    temp = soup_base.find_all('meta',{prop_name:attribute_name})
    for element in temp:
        out =(element.attrs["content"])    
    return out
        
def extract_video_info(my_url=None):
    #     print(my_url)
    page_html= urllib2.urlopen(my_url).read()
    sleep(0.002)
    #     print(page_html)
    soup_out = bs4.BeautifulSoup(page_html)    
    out_title=extract_meta(soup_out,"name","title").encode('utf-8')
    out_keys=extract_meta(soup_out,"name","keywords").encode('utf-8')

    temp = soup_out.find_all('script',{'type':'application/ld+json'})[0]
    description=extract_meta(soup_out,"itemprop","description").encode('utf-8')
    category=extract_meta(soup_out,"itemprop","genre").encode('utf-8')
    viewcount=extract_meta(soup_out,"itemprop","interactionCount").encode('utf-8')
    twitter_description=extract_meta(soup_out,"name","twitter:description").encode('utf-8')
    channelID=extract_meta(soup_out,"itemprop","channelId").encode('utf-8')

    for string in temp.strings:
        a=json.loads(string)
        author = a['itemListElement'][0]['item']['name'].encode('utf-8')    
        
    return out_title, out_keys,author, \
        category,viewcount,description, \
        twitter_description,channelID

# %%
try:
    t,k,a,c,v,d,td,chid = extract_video_info('https://www.youtube.com/watch?v=e7t4pTNZshA')
    print(t,k,a,c,v,d,td,chid)
except:
    pass
else:
    pass
# Out:
# https://www.youtube.com/watch?v=e7t4pTNZshA
# ('Hattie McDaniel winning Best Supporting Actress', 'Oscars, Academy, Awards, Hattie, McDaniel, Best, Supporting, Actress, Gone, with, the, Wind', 'Oscars', 'Entertainment', '372617', 'Fay Bainter presenting Hattie McDaniel with the Oscar\xc2\xae for Best Supporting Actress for her performance in "Gone With The Wind" at the 12th Academy Awards\xc2\xae in...', 'Fay Bainter presenting Hattie McDaniel with the Oscar\xc2\xae for Best Supporting Actress for her performance in "Gone With The Wind" at the 12th Academy Awards\xc2\xae in...', 'UCb-vZWBeWA5Q2818JmmJiqQ')

# %%
# print(t,k,a,c,v,d,td,chid)—
page_html= urllib2.urlopen(my_url).read()
sleep(0.5)
print(page_html)
# Out:
# <!DOCTYPE html><html lang="en" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/zN7GBFwfMP4uA6AR0HCoLQ.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/RxZJdnzeo3R5zSexge8UUaCWcynf_cDxXwCLxiixG1c.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/OLffGBTaF0XFOW1gnuHF0Z0EAVxt0G0biEntp43Qt6E.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/W4wDsBUluyw0tK3tykhXEfesZW2xOQ-xsNqO47m55DA.ttf)format('truetype');}</style><script name="www-ro
# ...

# %% [markdown]
# ### 1 read csv list of url

# %%
import pandas as pd
input_data = pd.read_csv('./sample_vids.txt',sep='\t')

# %% [markdown]
# ### 2 call extract_video_info to loop on list

# %%
i=0
input_data
for text in input_data["VIDID"]:
    test_url='https://www.youtube.com/watch?v=%s' %(text)
    try:
        
        t,k,a,c,v,d,td,chid = extract_video_info(test_url)
        print(t,k,a,c,v,d,td,chid)
    except:
        pass
    else:
        pass
# Out:
# https://www.youtube.com/watch?v=0XV3JQBX9sM
# ('DIDITH ROMERO in SA DILA NG APOY', 'TAGALOG, MOVIE', 'pilipinomovies', 'Film & Animation', '220224', 'SA DILA NG APOY,1987 * BOLD AND PENE MOVIE* CHECK MY BLOG--http://ratedxxxmovies.blogspot.com', 'SA DILA NG APOY,1987 * BOLD AND PENE MOVIE* CHECK MY BLOG--http://ratedxxxmovies.blogspot.com', 'UCh-eblga9rZwmUTuft22rtw')
# https://www.youtube.com/watch?v=EDLwppTAdW8
# ('M\xc3\xa1s Sabe el Diablo | Jencarlos Canela y Gaby Espino hacen el amor | Telemundo', 'Jencarlos Canela, Gaby Espino, TVTelemundo, TelemundoChannel', 'Telemundo FANS', 'Entertainment', '2789601', 'Jencarlos Canela y Gaby Espino en una de las escenas m\xc3\xa1s calientes de todos los tiempos en la televisi\xc3\xb3n.', 'Jencarlos Canela y Gaby Espino en una de las escenas m\xc3\xa1s calientes de todos los tiempos en la televisi\xc3\xb3n.', 'UCcgrOOB6iaytX1nG0UFmgTw')
# https://www.youtube.com/watch?v=mgLBmLoL2Aw
# ...

# %% [markdown]
# ### 3 Write to csv

# %%
import csv
from time import sleep

# %%
fieldnames = ['title','keywords', 'author','category','viewcount','description','twitter_desc','channelID']

with open('out.csv', 'w') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter='\t', quotechar='"', quoting=csv.QUOTE_NONE)
    spamwriter.writerow(fieldnames)
    for text in input_data["VIDID"]:
        my_url='https://www.youtube.com/watch?v=%s' %(text)
#         t,k,a,c,v,d,td,chid = extract_video_info(my_url)
#         sleep(0.01)
#         print(t,k,a,c,v,d,td,chid)
        try:
            t,k,a,c,v,d,td,chid = extract_video_info(my_url)
            sleep(0.01)
            print(t,k,a,c,v,d,td,chid)
            spamwriter.writerow([t,k,a,c,v,d,td,chid])
        except:
            pass

        continue
# Out:
# https://www.youtube.com/watch?v=0XV3JQBX9sM
# ('DIDITH ROMERO in SA DILA NG APOY', 'TAGALOG, MOVIE', 'pilipinomovies', 'Film & Animation', '220224', 'SA DILA NG APOY,1987 * BOLD AND PENE MOVIE* CHECK MY BLOG--http://ratedxxxmovies.blogspot.com', 'SA DILA NG APOY,1987 * BOLD AND PENE MOVIE* CHECK MY BLOG--http://ratedxxxmovies.blogspot.com', 'UCh-eblga9rZwmUTuft22rtw')
# https://www.youtube.com/watch?v=EDLwppTAdW8
# ('M\xc3\xa1s Sabe el Diablo | Jencarlos Canela y Gaby Espino hacen el amor | Telemundo', 'Jencarlos Canela, Gaby Espino, TVTelemundo, TelemundoChannel', 'Telemundo FANS', 'Entertainment', '2789601', 'Jencarlos Canela y Gaby Espino en una de las escenas m\xc3\xa1s calientes de todos los tiempos en la televisi\xc3\xb3n.', 'Jencarlos Canela y Gaby Espino en una de las escenas m\xc3\xa1s calientes de todos los tiempos en la televisi\xc3\xb3n.', 'UCcgrOOB6iaytX1nG0UFmgTw')
# https://www.youtube.com/watch?v=mgLBmLoL2Aw
# ...

# %%
def extract_info(input_csv=None,input_delimeter='\t',input_column="VIDID",output_csv=None, output_delimeter='\t',insert_mode=False,row_start=0):
    i=0
    input_data = pd.read_csv(input_csv,sep=input_delimeter)
    fieldnames = ['row_id','title','keywords', 'author','category','viewcount','description','twitter_desc','channelID']
    if insert_mode:
        with open(output_csv, 'ab') as csvfile:
            spamwriter = csv.writer(csvfile, delimiter=output_delimeter, quotechar='"', quoting=csv.QUOTE_NONE)
            for text in input_data[input_column]:
                if(i>=row_start):
                    my_url='https://www.youtube.com/watch?v=%s' %(text)

                    try:
                        t,k,a,c,v,d,td,chid = extract_video_info(my_url)
                        sleep(0.001)
                        #print(i,t,k,a,c,v,d,td,chid)
                        print(i)
                        spamwriter.writerow([i,t,k,a,c,v,d,td,chid])
                    except:
                        pass
                else:
                    pass
                i+=1
    else:
        with open(output_csv, 'wb') as csvfile:
            spamwriter = csv.writer(csvfile, delimiter=output_delimeter, quotechar='"', quoting=csv.QUOTE_NONE)
            spamwriter.writerow(fieldnames)
            for text in input_data[input_column]:
                if(i>=row_start):
                    my_url='https://www.youtube.com/watch?v=%s' %(text)

                    try:
                        t,k,a,c,v,d,td,chid = extract_video_info(my_url)
                        sleep(0.01)
                        #print(i,t,k,a,c,v,d,td,chid)
                        print(i)
                        spamwriter.writerow([i,t,k,a,c,v,d,td,chid])
                    except:
                        pass
                else:
                    pass
                i+=1

# %% [markdown]
# ## Run the extractor for the csv of videos
#
# - Just replace the **input_csv** variable with the input csv
# - Replace **output_csv with the** output csv file
# - Modify **input_delimeter** to suit the input csv file
# - Modify **output_delimeter** if you want other delimeters
# - Replace **input_column** with the column name of the video ID
# - Set **row_start** to start the processing from this Row

# %%
extract_info(input_csv='/data/raw_data/youtube_video_id/video_id_april.csv',
             output_csv='out.csv',input_delimeter=',' ,
             input_column="vidid", row_start=1000)
# Out:
# https://www.youtube.com/watch?v=TfKYWOUlq1o
# 1000
# https://www.youtube.com/watch?v=FkDpwF6-QiA
# 1001
# https://www.youtube.com/watch?v=ooiZovRI8mw
# 1002
# https://www.youtube.com/watch?v=aAz8MCO8fg8
# 1003
# https://www.youtube.com/watch?v=XP4qsKc8eF0
# https://www.youtube.com/watch?v=NlKRuse4FxE
# https://www.youtube.com/watch?v=tov22NtCMC4
# 1006
# https://www.youtube.com/watch?v=mtH53p2rNyg
# 1007
# https://www.youtube.com/watch?v=pCl_bVtg4yM
# 1008
# https://www.youtube.com/watch?v=FM-sfxQwn2U
# 1009
# https://www.youtube.com/watch?v=hNWbdJbskdU
# 1010
# https://www.youtube.com/watch?v=MT1r-p12ZGk
# 1011
# https://www.youtube.com/watch?v=SS9_CiUiesg
# 1012
# https://www.youtube.com/watch?v=aDcpfbMIGL8
# 1013
# https://www.youtube.com/watch?v=eegjhYyiwu8
# 1014
# https://www.youtube.com/watch?v=HYunfCZr2e8
# 1015
# https://www.youtube.com/watch?v=Kw8alCG29v4
# 1016
# https://www.youtube.com/watch?v=2KsPZdIwqJ8
# 1017
# https://www.youtube.com/watch?v=U38wbkI4xsE
# 1018
# ...
